# %%
import os
import json
import sqlite3
import threading
from dataclasses import dataclass
from datetime import datetime, timezone
from typing import Any, Dict, Optional, Tuple, List

import requests


# =========================
# Constants / Globals
# =========================
TROY_OZ_TO_GRAM = 31.1034768

_FX_CACHE: Dict[Tuple[str, str], float] = {}   # (TARGET, YYYY-MM-DD) -> rate
_stop_event = threading.Event()
_worker_thread: Optional[threading.Thread] = None


# =========================
# Exceptions / Models
# =========================
class ProviderError(RuntimeError):
    pass


class RateLimited(ProviderError):
    pass


@dataclass
class Quote:
    ts_utc: str
    source: str
    currency: str

    # Spot prijs (nu)
    price_per_troy_oz: float
    price_per_gram: float

    # Dagelijkse OHLC (als beschikbaar), anders fallback = spot
    open_per_troy_oz: Optional[float]
    high_per_troy_oz: Optional[float]
    close_per_troy_oz: Optional[float]

    fx_rate_to_target: Optional[float]
    raw_json: Dict[str, Any]


# =========================
# Configuration
# =========================
def _env_bool(name: str, default: str = "1") -> bool:
    return os.getenv(name, default).strip().lower() in ("1", "true", "yes", "y", "on")


def load_config() -> Dict[str, Any]:
    """
    Reads env vars each time, so it works well in Jupyter.
    """
    db_path = os.getenv("GOLD_DB_PATH", "gold_prices.sqlite")
    target_currency = os.getenv("GOLD_CURRENCY", "USD").upper()

    providers = [
        p.strip().lower()
        for p in os.getenv("GOLD_PROVIDERS", "gold-api,goldapi-net,metals-api,metals-dev").split(",")
        if p.strip()
    ]

    cfg = {
        "DB_PATH": db_path,
        "TARGET_CURRENCY": target_currency,
        "PROVIDERS": providers,
        "REQUEST_TIMEOUT": float(os.getenv("GOLD_TIMEOUT_SEC", "20")),
        "USER_AGENT": os.getenv("GOLD_USER_AGENT", "gold-collector/1.0"),
        "GOLDAPI_NET_KEY": os.getenv("GOLDAPI_KEY", ""),
        "METALS_API_KEY": os.getenv("METALS_API_KEY", ""),
        "METALS_DEV_KEY": os.getenv("METALS_DEV_KEY", ""),
        "INTERVAL_SEC": int(os.getenv("GOLD_INTERVAL_SEC", "60")),
        # probeert dag-OHLC bij metals-api (extra call); fallback is spot
        "INCLUDE_DAILY_OHLC": _env_bool("GOLD_INCLUDE_DAILY_OHLC", "1"),
    }
    return cfg


# =========================
# Database (with migration)
# =========================
def ensure_db(path: str) -> None:
    with sqlite3.connect(path) as con:
        con.execute(
            """
            CREATE TABLE IF NOT EXISTS gold_spot_prices (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                ts_utc TEXT NOT NULL,
                source TEXT NOT NULL,
                currency TEXT NOT NULL,

                price_per_troy_oz REAL NOT NULL,
                price_per_gram REAL NOT NULL,

                open_per_troy_oz REAL,
                high_per_troy_oz REAL,
                close_per_troy_oz REAL,

                fx_rate_to_target REAL,
                raw_json TEXT NOT NULL
            )
            """
        )

        # Migration: add missing columns if you updated the script
        cols = {row[1] for row in con.execute("PRAGMA table_info(gold_spot_prices)").fetchall()}

        if "fx_rate_to_target" not in cols:
            con.execute("ALTER TABLE gold_spot_prices ADD COLUMN fx_rate_to_target REAL")
        if "open_per_troy_oz" not in cols:
            con.execute("ALTER TABLE gold_spot_prices ADD COLUMN open_per_troy_oz REAL")
        if "high_per_troy_oz" not in cols:
            con.execute("ALTER TABLE gold_spot_prices ADD COLUMN high_per_troy_oz REAL")
        if "close_per_troy_oz" not in cols:
            con.execute("ALTER TABLE gold_spot_prices ADD COLUMN close_per_troy_oz REAL")

        con.execute("CREATE INDEX IF NOT EXISTS idx_gold_ts ON gold_spot_prices(ts_utc)")
        con.execute("CREATE INDEX IF NOT EXISTS idx_gold_source_cur ON gold_spot_prices(source, currency)")


def save_quote(path: str, q: Quote) -> None:
    with sqlite3.connect(path) as con:
        con.execute(
            """INSERT INTO gold_spot_prices
               (ts_utc, source, currency,
                price_per_troy_oz, price_per_gram,
                open_per_troy_oz, high_per_troy_oz, close_per_troy_oz,
                fx_rate_to_target, raw_json)
               VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)""",
            (
                q.ts_utc,
                q.source,
                q.currency,
                q.price_per_troy_oz,
                q.price_per_gram,
                q.open_per_troy_oz,
                q.high_per_troy_oz,
                q.close_per_troy_oz,
                q.fx_rate_to_target,
                json.dumps(q.raw_json, ensure_ascii=False),
            ),
        )


# =========================
# HTTP helpers
# =========================
def _http_get(cfg: Dict[str, Any], url: str, params: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
    headers = {"User-Agent": cfg["USER_AGENT"]}
    r = requests.get(url, params=params, headers=headers, timeout=cfg["REQUEST_TIMEOUT"])

    if r.status_code == 429:
        raise RateLimited("HTTP 429 rate limited: %s" % url)
    if r.status_code in (401, 403, 402):
        raise ProviderError("HTTP %s auth/quota: %s | %s" % (r.status_code, url, r.text[:200]))

    r.raise_for_status()
    try:
        return r.json()
    except Exception as e:
        raise ProviderError("Non-JSON response from %s: %s" % (url, e))


def _looks_like_rate_limit(payload: Dict[str, Any]) -> bool:
    txt = json.dumps(payload, ensure_ascii=False).lower()
    needles = ["rate limit", "too many", "quota", "exceeded", "limit reached", "requests per", "throttle"]
    return any(n in txt for n in needles)


# =========================
# FX (only needed when converting USD->other)
# =========================
def fx_usd_to(cfg: Dict[str, Any], target: str) -> float:
    target = target.upper()
    if target == "USD":
        return 1.0

    today = datetime.now(timezone.utc).date().isoformat()
    key = (target, today)
    if key in _FX_CACHE:
        return _FX_CACHE[key]

    data = _http_get(cfg, "https://api.frankfurter.app/latest", params={"from": "USD", "to": target})
    rate = data.get("rates", {}).get(target)
    if rate is None:
        raise ProviderError("FX rate USD->%s missing in response: %s" % (target, data))

    _FX_CACHE[key] = float(rate)
    return _FX_CACHE[key]


# =========================
# Providers
# =========================
def fetch_gold_api_dot_com(
    cfg: Dict[str, Any], target_currency: str
) -> Tuple[float, str, Dict[str, Any], Optional[float], Optional[float], Optional[float], Optional[float]]:
    """
    gold-api.com: returns XAU spot in USD per troy ounce.
    Daily OHLC not provided -> fallback to spot.
    """
    data = _http_get(cfg, "https://api.gold-api.com/price/XAU")
    if _looks_like_rate_limit(data):
        raise RateLimited("Rate limit payload (gold-api.com)")

    price_usd_oz = data.get("price")
    if price_usd_oz is None:
        raise ProviderError("No 'price' field (gold-api.com): %s" % data)

    price_usd_oz = float(price_usd_oz)

    if target_currency.upper() == "USD":
        spot = price_usd_oz
        return spot, "USD", data, None, spot, spot, spot  # O,H,C = spot

    fx = fx_usd_to(cfg, target_currency)
    spot = price_usd_oz * fx
    wrapped = {"source_payload": data, "fx_usd_to_target": fx, "target_currency": target_currency.upper()}
    return spot, target_currency.upper(), wrapped, fx, spot, spot, spot


def fetch_goldapi_net(
    cfg: Dict[str, Any], target_currency: str
) -> Tuple[float, str, Dict[str, Any], Optional[float], Optional[float], Optional[float], Optional[float]]:
    """
    goldapi.net: returns XAU in chosen currency, requires key.
    Daily OHLC not provided -> fallback to spot.
    """
    if not cfg["GOLDAPI_NET_KEY"]:
        raise ProviderError("GOLDAPI_KEY missing for goldapi.net")

    url = "https://app.goldapi.net/price/XAU/%s" % target_currency.upper()
    data = _http_get(cfg, url, params={"x-api-key": cfg["GOLDAPI_NET_KEY"]})
    if _looks_like_rate_limit(data):
        raise RateLimited("Rate limit payload (goldapi.net)")

    price = data.get("price")
    if price is None:
        raise ProviderError("No 'price' field (goldapi.net): %s" % data)

    spot = float(price)
    return spot, target_currency.upper(), data, None, spot, spot, spot


def _metals_api_pick_ohlc_value(rates: Dict[str, Any], key: str, symbol: str) -> Optional[float]:
    """
    Metals-API OHLC endpoint formats differ in the wild.
    Try:
      - rates[key] == float
      - rates[key] == {"EUR": float, ...}
    """
    v = rates.get(key)
    if v is None:
        return None
    if isinstance(v, (int, float)):
        return float(v)
    if isinstance(v, dict):
        vv = v.get(symbol)
        return None if vv is None else float(vv)
    return None


def fetch_metals_api(
    cfg: Dict[str, Any], target_currency: str
) -> Tuple[float, str, Dict[str, Any], Optional[float], Optional[float], Optional[float], Optional[float]]:
    """
    metals-api.com: base=USD symbols=XAU; commonly rates.XAU = XAU per USD, so USD per XAU = 1/rates.XAU.
    If enabled, also tries the daily OHLC endpoint for open/high/close (fallback to spot).
    """
    if not cfg["METALS_API_KEY"]:
        raise ProviderError("METALS_API_KEY missing for metals-api.com")

    latest = _http_get(
        cfg,
        "https://metals-api.com/api/latest",
        params={"access_key": cfg["METALS_API_KEY"], "base": "USD", "symbols": "XAU"},
    )

    if not latest.get("success", True) and "error" in latest:
        if _looks_like_rate_limit(latest):
            raise RateLimited("Rate limit payload (metals-api.com)")
        raise ProviderError("metals-api error: %s" % latest.get("error"))

    xau = latest.get("rates", {}).get("XAU")
    if xau is None:
        raise ProviderError("No rates.XAU (metals-api.com): %s" % latest)

    usd_per_xau = 1.0 / float(xau)

    fx: Optional[float] = None
    symbol = target_currency.upper()
    if symbol == "USD":
        spot = usd_per_xau
    else:
        fx = fx_usd_to(cfg, symbol)
        spot = usd_per_xau * fx

    # Defaults: fallback to spot
    day_open = spot
    day_high = spot
    day_close = spot
    ohlc_payload: Optional[Dict[str, Any]] = None

    if cfg.get("INCLUDE_DAILY_OHLC", True):
        try:
            date_iso = datetime.now(timezone.utc).date().isoformat()
            ohlc_payload = _http_get(
                cfg,
                f"https://metals-api.com/api/open-high-low-close/{date_iso}",
                params={"access_key": cfg["METALS_API_KEY"], "base": "XAU", "symbols": symbol},
            )

            if not ohlc_payload.get("success", True) and "error" in ohlc_payload:
                # niet hard falen; terugvallen op spot
                ohlc_payload = {"error": ohlc_payload.get("error"), "note": "OHLC failed; used spot fallback"}

            rates = (ohlc_payload.get("rates") or {}) if isinstance(ohlc_payload, dict) else {}

            o = _metals_api_pick_ohlc_value(rates, "open", symbol)
            h = _metals_api_pick_ohlc_value(rates, "high", symbol)
            c = _metals_api_pick_ohlc_value(rates, "close", symbol)

            if o is not None:
                day_open = o
            if h is not None:
                day_high = h
            if c is not None:
                day_close = c
        except Exception as e:
            ohlc_payload = {"note": "OHLC exception; used spot fallback", "exception": str(e)}

    wrapped: Dict[str, Any] = {
        "source_payload_latest": latest,
        "source_payload_ohlc": ohlc_payload,
        "note_latest": "spot computed as 1/rates.XAU then optionally USD->target FX",
        "target_currency": symbol,
    }
    if fx is not None:
        wrapped["fx_usd_to_target"] = fx

    return spot, symbol, wrapped, fx, day_open, day_high, day_close


def fetch_metals_dev(
    cfg: Dict[str, Any], target_currency: str
) -> Tuple[float, str, Dict[str, Any], Optional[float], Optional[float], Optional[float], Optional[float]]:
    """
    metals.dev: requires key; response structure can vary, we try multiple field paths.
    Daily OHLC not provided -> fallback to spot.
    """
    if not cfg["METALS_DEV_KEY"]:
        raise ProviderError("METALS_DEV_KEY missing for metals.dev")

    data = _http_get(
        cfg,
        "https://api.metals.dev/v1/metal/spot",
        params={"api_key": cfg["METALS_DEV_KEY"], "metal": "XAU", "currency": target_currency.upper()},
    )

    if _looks_like_rate_limit(data):
        raise RateLimited("Rate limit payload (metals.dev)")

    candidates = [
        ("price",),
        ("rate",),
        ("result", "price"),
        ("data", "price"),
        ("metal", "price"),
    ]

    def get_nested(d: Dict[str, Any], path: Tuple[str, ...]) -> Optional[Any]:
        cur: Any = d
        for k in path:
            if not isinstance(cur, dict) or k not in cur:
                return None
            cur = cur[k]
        return cur

    price = None
    for path in candidates:
        v = get_nested(data, path)
        if v is not None:
            price = v
            break

    if price is None:
        raise ProviderError("Could not find price in metals.dev response: %s" % data)

    spot = float(price)
    return spot, target_currency.upper(), data, None, spot, spot, spot


# =========================
# Orchestrator / Collector
# =========================
def fetch_with_failover(cfg: Dict[str, Any]) -> Quote:
    target_currency = cfg["TARGET_CURRENCY"]
    providers = cfg["PROVIDERS"]

    ts_utc = datetime.now(timezone.utc).isoformat(timespec="seconds")
    errors: List[str] = []

    for p in providers:
        try:
            if p == "gold-api":
                spot_oz, cur, raw, fx, day_open, day_high, day_close = fetch_gold_api_dot_com(cfg, target_currency)
                source = "gold-api.com"
            elif p == "goldapi-net":
                spot_oz, cur, raw, fx, day_open, day_high, day_close = fetch_goldapi_net(cfg, target_currency)
                source = "goldapi.net"
            elif p == "metals-api":
                spot_oz, cur, raw, fx, day_open, day_high, day_close = fetch_metals_api(cfg, target_currency)
                source = "metals-api.com"
            elif p == "metals-dev":
                spot_oz, cur, raw, fx, day_open, day_high, day_close = fetch_metals_dev(cfg, target_currency)
                source = "metals.dev"
            else:
                errors.append("%s: ERROR: unknown provider" % p)
                continue

            price_g = float(spot_oz) / TROY_OZ_TO_GRAM

            return Quote(
                ts_utc=ts_utc,
                source=source,
                currency=cur,
                price_per_troy_oz=float(spot_oz),
                price_per_gram=float(price_g),
                open_per_troy_oz=None if day_open is None else float(day_open),
                high_per_troy_oz=None if day_high is None else float(day_high),
                close_per_troy_oz=None if day_close is None else float(day_close),
                fx_rate_to_target=fx,
                raw_json=raw,
            )

        except RateLimited as e:
            errors.append("%s: RATE_LIMIT: %s" % (p, e))
            continue
        except (requests.RequestException, ProviderError) as e:
            errors.append("%s: ERROR: %s" % (p, e))
            continue

    raise RuntimeError("All providers failed:\n- " + "\n- ".join(errors))


def collect_once() -> Quote:
    cfg = load_config()
    ensure_db(cfg["DB_PATH"])
    q = fetch_with_failover(cfg)
    save_quote(cfg["DB_PATH"], q)

    o = "-" if q.open_per_troy_oz is None else f"{q.open_per_troy_oz:.2f}"
    h = "-" if q.high_per_troy_oz is None else f"{q.high_per_troy_oz:.2f}"
    c = "-" if q.close_per_troy_oz is None else f"{q.close_per_troy_oz:.2f}"

    print(
        "OK %s | %s | %s spot=%.2f/oz | O=%s H=%s C=%s | %.2f/g | DB=%s"
        % (q.ts_utc, q.source, q.currency, q.price_per_troy_oz, o, h, c, q.price_per_gram, cfg["DB_PATH"])
    )
    return q


# =========================
# Periodic runner (Jupyter-friendly)
# =========================
def start_collector(interval_sec: Optional[int] = None) -> None:
    """
    Runs in a background thread (recommended for Jupyter).
    Stop via stop_collector().
    """
    global _worker_thread
    cfg = load_config()

    if interval_sec is None:
        interval_sec = int(cfg["INTERVAL_SEC"])

    if _worker_thread is not None and _worker_thread.is_alive():
        print("[collector] Already running")
        return

    _stop_event.clear()

    def worker():
        while not _stop_event.is_set():
            try:
                collect_once()
            except Exception as e:
                print("[collector] ERROR:", e)
            _stop_event.wait(interval_sec)

    _worker_thread = threading.Thread(target=worker, daemon=True)
    _worker_thread.start()
    print(
        "[collector] Started (interval=%ss, currency=%s, providers=%s)"
        % (interval_sec, cfg["TARGET_CURRENCY"], ",".join(cfg["PROVIDERS"]))
    )


def stop_collector() -> None:
    _stop_event.set()
    print("[collector] Stop signal sent")


# =========================
# Optional: blocking loop (non-thread)
# =========================
def run_forever(interval_sec: Optional[int] = None) -> None:
    """
    Blocking loop (useful outside Jupyter). Stop with KeyboardInterrupt.
    """
    cfg = load_config()
    if interval_sec is None:
        interval_sec = int(cfg["INTERVAL_SEC"])

    print("[collector] Running forever (interval=%ss). Ctrl+C to stop." % interval_sec)
    while True:
        collect_once()
        threading.Event().wait(interval_sec)


# =========================
# Defaults for your use-case (USD)
# =========================
# You can set these in Jupyter before calling start_collector()/collect_once()
# os.environ["GOLD_CURRENCY"] = "USD"
# os.environ["GOLD_PROVIDERS"] = "gold-api,goldapi-net,metals-api,metals-dev"
# os.environ["GOLD_DB_PATH"] = "gold_prices.sqlite"
# os.environ["GOLD_INTERVAL_SEC"] = "60"
# os.environ["GOLD_INCLUDE_DAILY_OHLC"] = "1"

# %%
import os
os.environ["GOLD_CURRENCY"] = "USD"
os.environ["GOLD_PROVIDERS"] = "gold-api,goldapi-net,metals-api,metals-dev"
os.environ["GOLD_DB_PATH"] = "gold_prices.sqlite"
os.environ["GOLD_INTERVAL_SEC"] = "60"  # elke minuut
# Out:
# OK 2025-12-22T08:01:30+00:00 | gold-api.com | USD spot=4415.50/oz | O=4415.50 H=4415.50 C=4415.50 | 141.96/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:02:24+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:02:30+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:03:24+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:03:30+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:04:24+00:00 | gold-api.com | USD spot=4413.80/oz | O=4413.80 H=4413.80 C=4413.80 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:04:30+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:05:25+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:05:30+00:00 | gold-api.com | USD spot=4413.70/oz | O=4413.70 H=4413.70 C=4413.70 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:06:25+00:00 | gold-api.com | USD spot=4413.70/oz | O=4413.70 H=4413.70 C=4413.70 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:06:30+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:07:25+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:07:30+00:00 | gold-api.com | USD spot=4413.10/oz | O=4413.10 H=4413.10 C=4413.10 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:08:25+00:00 | gold-api.com | USD spot=4413.10/oz | O=4413.10 H=4413.10 C=4413.10 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:08:30+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:09:25+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:09:31+00:00 | gold-api.com | USD spot=4414.60/oz | O=4414.60 H=4414.60 C=4414.60 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:10:25+00:00 | gold-api.com | USD spot=4414.60/oz | O=4414.60 H=4414.60 C=4414.60 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:10:31+00:00 | gold-api.com | USD spot=4414.80/oz | O=4414.80 H=4414.80 C=4414.80 | 141.94/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:11:25+00:00 | gold-api.com | USD spot=4414.80/oz | O=4414.80 H=4414.80 C=4414.80 | 141.94/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:11:31+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:12:25+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:12:31+00:00 | gold-api.com | USD spot=4414.40/oz | O=4414.40 H=4414.40 C=4414.40 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:13:26+00:00 | gold-api.com | USD spot=4414.40/oz | O=4414.40 H=4414.40 C=4414.40 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:13:31+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:14:26+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:14:31+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:15:26+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:15:31+00:00 | gold-api.com | USD spot=4413.60/oz | O=4413.60 H=4413.60 C=4413.60 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:16:26+00:00 | gold-api.com | USD spot=4413.60/oz | O=4413.60 H=4413.60 C=4413.60 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:16:31+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:17:26+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:17:31+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:18:26+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:18:31+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:19:26+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:19:32+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:20:26+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:20:32+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:21:26+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:21:32+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:22:26+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:22:33+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:23:27+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:23:33+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:24:27+00:00 | gold-api.com | USD spot=4413.00/oz | O=4413.00 H=4413.00 C=4413.00 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:24:33+00:00 | gold-api.com | USD spot=4413.70/oz | O=4413.70 H=4413.70 C=4413.70 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:25:27+00:00 | gold-api.com | USD spot=4413.70/oz | O=4413.70 H=4413.70 C=4413.70 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:25:33+00:00 | gold-api.com | USD spot=4413.20/oz | O=4413.20 H=4413.20 C=4413.20 | 141.89/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:26:27+00:00 | gold-api.com | USD spot=4413.20/oz | O=4413.20 H=4413.20 C=4413.20 | 141.89/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:26:33+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:27:28+00:00 | gold-api.com | USD spot=4412.90/oz | O=4412.90 H=4412.90 C=4412.90 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:27:34+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:28:28+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:28:34+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:29:28+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:29:34+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:30:28+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:30:35+00:00 | gold-api.com | USD spot=4414.30/oz | O=4414.30 H=4414.30 C=4414.30 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:31:29+00:00 | gold-api.com | USD spot=4414.30/oz | O=4414.30 H=4414.30 C=4414.30 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:31:35+00:00 | gold-api.com | USD spot=4415.60/oz | O=4415.60 H=4415.60 C=4415.60 | 141.96/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:32:29+00:00 | gold-api.com | USD spot=4415.60/oz | O=4415.60 H=4415.60 C=4415.60 | 141.96/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:32:35+00:00 | gold-api.com | USD spot=4414.90/oz | O=4414.90 H=4414.90 C=4414.90 | 141.94/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:33:29+00:00 | gold-api.com | USD spot=4414.90/oz | O=4414.90 H=4414.90 C=4414.90 | 141.94/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:33:35+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:34:29+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:34:36+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:35:30+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:35:36+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:36:30+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:36:36+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:37:30+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:37:37+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:38:31+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:38:37+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:39:31+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:39:37+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:40:31+00:00 | gold-api.com | USD spot=4408.90/oz | O=4408.90 H=4408.90 C=4408.90 | 141.75/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:40:37+00:00 | gold-api.com | USD spot=4408.90/oz | O=4408.90 H=4408.90 C=4408.90 | 141.75/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:41:31+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# [collector] ERROR: All providers failed:
# - gold-api: ERROR: HTTPSConnectionPool(host='api.gold-api.com', port=443): Max retries exceeded with url: /price/XAU (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f871d194cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# - goldapi-net: ERROR: GOLDAPI_KEY missing for goldapi.net
# - metals-api: ERROR: METALS_API_KEY missing for metals-api.com
# - metals-dev: ERROR: METALS_DEV_KEY missing for metals.dev
# OK 2025-12-22T08:42:32+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:42:38+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:43:32+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:43:38+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:44:33+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:44:38+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:45:33+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:45:39+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:46:33+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:46:39+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:47:33+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:47:39+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:48:34+00:00 | gold-api.com | USD spot=4410.90/oz | O=4410.90 H=4410.90 C=4410.90 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:48:39+00:00 | gold-api.com | USD spot=4410.90/oz | O=4410.90 H=4410.90 C=4410.90 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:49:34+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:49:39+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:50:34+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:50:40+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:51:35+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:51:40+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:52:35+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:52:40+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:53:35+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:53:40+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:54:35+00:00 | gold-api.com | USD spot=4409.10/oz | O=4409.10 H=4409.10 C=4409.10 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:54:40+00:00 | gold-api.com | USD spot=4409.10/oz | O=4409.10 H=4409.10 C=4409.10 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:55:35+00:00 | gold-api.com | USD spot=4408.80/oz | O=4408.80 H=4408.80 C=4408.80 | 141.75/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:55:40+00:00 | gold-api.com | USD spot=4408.80/oz | O=4408.80 H=4408.80 C=4408.80 | 141.75/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:56:35+00:00 | gold-api.com | USD spot=4408.10/oz | O=4408.10 H=4408.10 C=4408.10 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:56:40+00:00 | gold-api.com | USD spot=4408.10/oz | O=4408.10 H=4408.10 C=4408.10 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:57:35+00:00 | gold-api.com | USD spot=4408.00/oz | O=4408.00 H=4408.00 C=4408.00 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:57:40+00:00 | gold-api.com | USD spot=4408.00/oz | O=4408.00 H=4408.00 C=4408.00 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:58:35+00:00 | gold-api.com | USD spot=4408.00/oz | O=4408.00 H=4408.00 C=4408.00 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:58:41+00:00 | gold-api.com | USD spot=4408.00/oz | O=4408.00 H=4408.00 C=4408.00 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:59:35+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T08:59:41+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:00:35+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:00:41+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:01:36+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:01:41+00:00 | gold-api.com | USD spot=4409.30/oz | O=4409.30 H=4409.30 C=4409.30 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:02:36+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:02:41+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:03:36+00:00 | gold-api.com | USD spot=4409.50/oz | O=4409.50 H=4409.50 C=4409.50 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:03:41+00:00 | gold-api.com | USD spot=4409.50/oz | O=4409.50 H=4409.50 C=4409.50 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:04:36+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:04:41+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:05:36+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:05:41+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:06:36+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:06:41+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:07:36+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:07:41+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:08:40+00:00 | gold-api.com | USD spot=4412.60/oz | O=4412.60 H=4412.60 C=4412.60 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:08:46+00:00 | gold-api.com | USD spot=4412.60/oz | O=4412.60 H=4412.60 C=4412.60 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:38:42+00:00 | gold-api.com | USD spot=4413.90/oz | O=4413.90 H=4413.90 C=4413.90 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:38:48+00:00 | gold-api.com | USD spot=4413.90/oz | O=4413.90 H=4413.90 C=4413.90 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:39:43+00:00 | gold-api.com | USD spot=4413.20/oz | O=4413.20 H=4413.20 C=4413.20 | 141.89/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:39:48+00:00 | gold-api.com | USD spot=4413.20/oz | O=4413.20 H=4413.20 C=4413.20 | 141.89/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:40:47+00:00 | gold-api.com | USD spot=4413.50/oz | O=4413.50 H=4413.50 C=4413.50 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T09:40:52+00:00 | gold-api.com | USD spot=4413.50/oz | O=4413.50 H=4413.50 C=4413.50 | 141.90/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:09:59+00:00 | gold-api.com | USD spot=4416.70/oz | O=4416.70 H=4416.70 C=4416.70 | 142.00/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:10:04+00:00 | gold-api.com | USD spot=4416.70/oz | O=4416.70 H=4416.70 C=4416.70 | 142.00/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:10:59+00:00 | gold-api.com | USD spot=4415.40/oz | O=4415.40 H=4415.40 C=4415.40 | 141.96/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:11:04+00:00 | gold-api.com | USD spot=4415.40/oz | O=4415.40 H=4415.40 C=4415.40 | 141.96/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:11:59+00:00 | gold-api.com | USD spot=4414.60/oz | O=4414.60 H=4414.60 C=4414.60 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:12:04+00:00 | gold-api.com | USD spot=4414.60/oz | O=4414.60 H=4414.60 C=4414.60 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:12:59+00:00 | gold-api.com | USD spot=4414.40/oz | O=4414.40 H=4414.40 C=4414.40 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:13:04+00:00 | gold-api.com | USD spot=4414.40/oz | O=4414.40 H=4414.40 C=4414.40 | 141.93/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:13:59+00:00 | gold-api.com | USD spot=4415.20/oz | O=4415.20 H=4415.20 C=4415.20 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:14:04+00:00 | gold-api.com | USD spot=4415.20/oz | O=4415.20 H=4415.20 C=4415.20 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:15:00+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:15:04+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:16:00+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:16:04+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:17:00+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:17:04+00:00 | gold-api.com | USD spot=4415.00/oz | O=4415.00 H=4415.00 C=4415.00 | 141.95/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:31:39+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:31:43+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:32:39+00:00 | gold-api.com | USD spot=4408.60/oz | O=4408.60 H=4408.60 C=4408.60 | 141.74/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:32:43+00:00 | gold-api.com | USD spot=4408.60/oz | O=4408.60 H=4408.60 C=4408.60 | 141.74/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:33:39+00:00 | gold-api.com | USD spot=4408.20/oz | O=4408.20 H=4408.20 C=4408.20 | 141.73/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:33:44+00:00 | gold-api.com | USD spot=4408.20/oz | O=4408.20 H=4408.20 C=4408.20 | 141.73/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:34:39+00:00 | gold-api.com | USD spot=4408.20/oz | O=4408.20 H=4408.20 C=4408.20 | 141.73/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:34:44+00:00 | gold-api.com | USD spot=4408.20/oz | O=4408.20 H=4408.20 C=4408.20 | 141.73/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:35:39+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:35:44+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:36:39+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:36:44+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:37:39+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:37:44+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:38:39+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:38:44+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:39:40+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:39:44+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:40:40+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:40:44+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:41:40+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:41:44+00:00 | gold-api.com | USD spot=4411.60/oz | O=4411.60 H=4411.60 C=4411.60 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:42:40+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:42:44+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:43:40+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:43:45+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:44:40+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:44:45+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:45:40+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:45:45+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:46:40+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:46:45+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:47:40+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:47:45+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:48:40+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:48:45+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:49:41+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:49:45+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:50:41+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:50:45+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:51:41+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:51:45+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:52:41+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:52:45+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:53:41+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:53:45+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:54:41+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:54:46+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:55:41+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:55:46+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:56:41+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:56:46+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:57:41+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:57:46+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:58:41+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:58:46+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:59:41+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T10:59:46+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:00:42+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:00:46+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:01:42+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:01:46+00:00 | gold-api.com | USD spot=4409.90/oz | O=4409.90 H=4409.90 C=4409.90 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:02:42+00:00 | gold-api.com | USD spot=4407.90/oz | O=4407.90 H=4407.90 C=4407.90 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:02:46+00:00 | gold-api.com | USD spot=4407.90/oz | O=4407.90 H=4407.90 C=4407.90 | 141.72/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:03:42+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:03:46+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:04:42+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:04:46+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:05:42+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:05:47+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:06:42+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:06:47+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:07:42+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:07:47+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:08:42+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:08:47+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:09:42+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:09:47+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:10:43+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:10:47+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:11:43+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:11:47+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:12:43+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:12:48+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:13:43+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:13:48+00:00 | gold-api.com | USD spot=4409.70/oz | O=4409.70 H=4409.70 C=4409.70 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:14:44+00:00 | gold-api.com | USD spot=4409.50/oz | O=4409.50 H=4409.50 C=4409.50 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:14:49+00:00 | gold-api.com | USD spot=4409.50/oz | O=4409.50 H=4409.50 C=4409.50 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:15:45+00:00 | gold-api.com | USD spot=4409.80/oz | O=4409.80 H=4409.80 C=4409.80 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:15:49+00:00 | gold-api.com | USD spot=4409.80/oz | O=4409.80 H=4409.80 C=4409.80 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:16:45+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:16:50+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:17:46+00:00 | gold-api.com | USD spot=4409.40/oz | O=4409.40 H=4409.40 C=4409.40 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:17:50+00:00 | gold-api.com | USD spot=4409.40/oz | O=4409.40 H=4409.40 C=4409.40 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:18:46+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:18:51+00:00 | gold-api.com | USD spot=4410.20/oz | O=4410.20 H=4410.20 C=4410.20 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:19:46+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:19:51+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:20:47+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:20:52+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:21:47+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:21:52+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:22:47+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:22:53+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:23:47+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:23:53+00:00 | gold-api.com | USD spot=4410.70/oz | O=4410.70 H=4410.70 C=4410.70 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:24:48+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:24:53+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:25:48+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:25:53+00:00 | gold-api.com | USD spot=4409.60/oz | O=4409.60 H=4409.60 C=4409.60 | 141.77/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:26:48+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:26:54+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:27:49+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:27:54+00:00 | gold-api.com | USD spot=4410.30/oz | O=4410.30 H=4410.30 C=4410.30 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:28:50+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:28:55+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:29:50+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:29:55+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:30:50+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:30:55+00:00 | gold-api.com | USD spot=4411.00/oz | O=4411.00 H=4411.00 C=4411.00 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:31:51+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:31:56+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:32:51+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:32:56+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:33:51+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:33:56+00:00 | gold-api.com | USD spot=4411.90/oz | O=4411.90 H=4411.90 C=4411.90 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:34:52+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:34:57+00:00 | gold-api.com | USD spot=4411.70/oz | O=4411.70 H=4411.70 C=4411.70 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:35:52+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:35:57+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:36:52+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:36:57+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:37:52+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:37:57+00:00 | gold-api.com | USD spot=4411.30/oz | O=4411.30 H=4411.30 C=4411.30 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:38:53+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:38:57+00:00 | gold-api.com | USD spot=4411.20/oz | O=4411.20 H=4411.20 C=4411.20 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:39:53+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:39:58+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:40:53+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:40:58+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:41:54+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:41:58+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:42:54+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:42:59+00:00 | gold-api.com | USD spot=4412.40/oz | O=4412.40 H=4412.40 C=4412.40 | 141.86/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:43:54+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:43:59+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:44:55+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:44:59+00:00 | gold-api.com | USD spot=4411.10/oz | O=4411.10 H=4411.10 C=4411.10 | 141.82/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:45:55+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:45:59+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:46:55+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:47:00+00:00 | gold-api.com | USD spot=4411.80/oz | O=4411.80 H=4411.80 C=4411.80 | 141.84/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:47:55+00:00 | gold-api.com | USD spot=4411.40/oz | O=4411.40 H=4411.40 C=4411.40 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:48:00+00:00 | gold-api.com | USD spot=4411.40/oz | O=4411.40 H=4411.40 C=4411.40 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:48:56+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:49:00+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:49:56+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:50:01+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:50:56+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:51:01+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:51:57+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:52:01+00:00 | gold-api.com | USD spot=4410.40/oz | O=4410.40 H=4410.40 C=4410.40 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:52:57+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:53:02+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:53:57+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:54:02+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:54:57+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:55:02+00:00 | gold-api.com | USD spot=4410.50/oz | O=4410.50 H=4410.50 C=4410.50 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:55:58+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:56:02+00:00 | gold-api.com | USD spot=4410.10/oz | O=4410.10 H=4410.10 C=4410.10 | 141.79/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:56:58+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:57:03+00:00 | gold-api.com | USD spot=4410.00/oz | O=4410.00 H=4410.00 C=4410.00 | 141.78/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:57:58+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:58:03+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:58:59+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:59:03+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T11:59:59+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:00:04+00:00 | gold-api.com | USD spot=4410.80/oz | O=4410.80 H=4410.80 C=4410.80 | 141.81/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:00:59+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:01:04+00:00 | gold-api.com | USD spot=4410.60/oz | O=4410.60 H=4410.60 C=4410.60 | 141.80/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:02:00+00:00 | gold-api.com | USD spot=4411.50/oz | O=4411.50 H=4411.50 C=4411.50 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:02:04+00:00 | gold-api.com | USD spot=4411.50/oz | O=4411.50 H=4411.50 C=4411.50 | 141.83/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:03:00+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:03:04+00:00 | gold-api.com | USD spot=4412.00/oz | O=4412.00 H=4412.00 C=4412.00 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:04:00+00:00 | gold-api.com | USD spot=4413.80/oz | O=4413.80 H=4413.80 C=4413.80 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:04:05+00:00 | gold-api.com | USD spot=4413.80/oz | O=4413.80 H=4413.80 C=4413.80 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:05:00+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:05:05+00:00 | gold-api.com | USD spot=4414.00/oz | O=4414.00 H=4414.00 C=4414.00 | 141.91/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:06:01+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:06:05+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:07:01+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:07:06+00:00 | gold-api.com | USD spot=4414.20/oz | O=4414.20 H=4414.20 C=4414.20 | 141.92/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:08:01+00:00 | gold-api.com | USD spot=4413.10/oz | O=4413.10 H=4413.10 C=4413.10 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:08:06+00:00 | gold-api.com | USD spot=4413.10/oz | O=4413.10 H=4413.10 C=4413.10 | 141.88/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:09:02+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:09:06+00:00 | gold-api.com | USD spot=4412.50/oz | O=4412.50 H=4412.50 C=4412.50 | 141.87/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:10:02+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:10:06+00:00 | gold-api.com | USD spot=4412.10/oz | O=4412.10 H=4412.10 C=4412.10 | 141.85/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:11:02+00:00 | gold-api.com | USD spot=4409.20/oz | O=4409.20 H=4409.20 C=4409.20 | 141.76/g | DB=gold_prices.sqlite
# OK 2025-12-22T12:11:06+00:00 | gold-api.com | USD spot=4409.20/oz | O=4409.20 H=4409.20 C=4409.20 | 141.76/g | DB=gold_prices.sqlite
# ...
# OK 2025-12-26T07:37:28+00:00 | gold-api.com | USD spot=4512.30/oz | O=4512.30 H=4512.30 C=4512.30 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:37:33+00:00 | gold-api.com | USD spot=4512.30/oz | O=4512.30 H=4512.30 C=4512.30 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:38:28+00:00 | gold-api.com | USD spot=4513.60/oz | O=4513.60 H=4513.60 C=4513.60 | 145.12/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:38:33+00:00 | gold-api.com | USD spot=4513.60/oz | O=4513.60 H=4513.60 C=4513.60 | 145.12/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:39:28+00:00 | gold-api.com | USD spot=4512.10/oz | O=4512.10 H=4512.10 C=4512.10 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:39:33+00:00 | gold-api.com | USD spot=4512.10/oz | O=4512.10 H=4512.10 C=4512.10 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:40:28+00:00 | gold-api.com | USD spot=4512.00/oz | O=4512.00 H=4512.00 C=4512.00 | 145.06/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:40:34+00:00 | gold-api.com | USD spot=4512.00/oz | O=4512.00 H=4512.00 C=4512.00 | 145.06/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:41:28+00:00 | gold-api.com | USD spot=4511.20/oz | O=4511.20 H=4511.20 C=4511.20 | 145.04/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:41:34+00:00 | gold-api.com | USD spot=4511.20/oz | O=4511.20 H=4511.20 C=4511.20 | 145.04/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:42:28+00:00 | gold-api.com | USD spot=4511.80/oz | O=4511.80 H=4511.80 C=4511.80 | 145.06/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:42:34+00:00 | gold-api.com | USD spot=4511.80/oz | O=4511.80 H=4511.80 C=4511.80 | 145.06/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:43:28+00:00 | gold-api.com | USD spot=4511.80/oz | O=4511.80 H=4511.80 C=4511.80 | 145.06/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:43:34+00:00 | gold-api.com | USD spot=4512.60/oz | O=4512.60 H=4512.60 C=4512.60 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:44:28+00:00 | gold-api.com | USD spot=4512.60/oz | O=4512.60 H=4512.60 C=4512.60 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:44:34+00:00 | gold-api.com | USD spot=4510.70/oz | O=4510.70 H=4510.70 C=4510.70 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:45:28+00:00 | gold-api.com | USD spot=4510.70/oz | O=4510.70 H=4510.70 C=4510.70 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:45:34+00:00 | gold-api.com | USD spot=4509.60/oz | O=4509.60 H=4509.60 C=4509.60 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:46:28+00:00 | gold-api.com | USD spot=4509.60/oz | O=4509.60 H=4509.60 C=4509.60 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:46:34+00:00 | gold-api.com | USD spot=4510.50/oz | O=4510.50 H=4510.50 C=4510.50 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:47:29+00:00 | gold-api.com | USD spot=4510.50/oz | O=4510.50 H=4510.50 C=4510.50 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:47:34+00:00 | gold-api.com | USD spot=4510.40/oz | O=4510.40 H=4510.40 C=4510.40 | 145.01/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:48:29+00:00 | gold-api.com | USD spot=4510.40/oz | O=4510.40 H=4510.40 C=4510.40 | 145.01/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:48:34+00:00 | gold-api.com | USD spot=4510.00/oz | O=4510.00 H=4510.00 C=4510.00 | 145.00/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:49:29+00:00 | gold-api.com | USD spot=4510.00/oz | O=4510.00 H=4510.00 C=4510.00 | 145.00/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:49:34+00:00 | gold-api.com | USD spot=4509.80/oz | O=4509.80 H=4509.80 C=4509.80 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:50:29+00:00 | gold-api.com | USD spot=4509.80/oz | O=4509.80 H=4509.80 C=4509.80 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:50:34+00:00 | gold-api.com | USD spot=4509.60/oz | O=4509.60 H=4509.60 C=4509.60 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:51:29+00:00 | gold-api.com | USD spot=4509.60/oz | O=4509.60 H=4509.60 C=4509.60 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:51:35+00:00 | gold-api.com | USD spot=4510.60/oz | O=4510.60 H=4510.60 C=4510.60 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:52:29+00:00 | gold-api.com | USD spot=4510.60/oz | O=4510.60 H=4510.60 C=4510.60 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:52:35+00:00 | gold-api.com | USD spot=4510.60/oz | O=4510.60 H=4510.60 C=4510.60 | 145.02/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:53:29+00:00 | gold-api.com | USD spot=4510.40/oz | O=4510.40 H=4510.40 C=4510.40 | 145.01/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:53:36+00:00 | gold-api.com | USD spot=4509.80/oz | O=4509.80 H=4509.80 C=4509.80 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:54:29+00:00 | gold-api.com | USD spot=4509.80/oz | O=4509.80 H=4509.80 C=4509.80 | 144.99/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:54:36+00:00 | gold-api.com | USD spot=4509.10/oz | O=4509.10 H=4509.10 C=4509.10 | 144.97/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:55:30+00:00 | gold-api.com | USD spot=4509.10/oz | O=4509.10 H=4509.10 C=4509.10 | 144.97/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:55:37+00:00 | gold-api.com | USD spot=4510.00/oz | O=4510.00 H=4510.00 C=4510.00 | 145.00/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:56:30+00:00 | gold-api.com | USD spot=4510.00/oz | O=4510.00 H=4510.00 C=4510.00 | 145.00/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:56:37+00:00 | gold-api.com | USD spot=4511.10/oz | O=4511.10 H=4511.10 C=4511.10 | 145.04/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:57:30+00:00 | gold-api.com | USD spot=4511.10/oz | O=4511.10 H=4511.10 C=4511.10 | 145.04/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:57:37+00:00 | gold-api.com | USD spot=4510.80/oz | O=4510.80 H=4510.80 C=4510.80 | 145.03/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:58:30+00:00 | gold-api.com | USD spot=4510.80/oz | O=4510.80 H=4510.80 C=4510.80 | 145.03/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:58:37+00:00 | gold-api.com | USD spot=4511.60/oz | O=4511.60 H=4511.60 C=4511.60 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:59:30+00:00 | gold-api.com | USD spot=4511.60/oz | O=4511.60 H=4511.60 C=4511.60 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T07:59:37+00:00 | gold-api.com | USD spot=4511.50/oz | O=4511.50 H=4511.50 C=4511.50 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:00:30+00:00 | gold-api.com | USD spot=4511.50/oz | O=4511.50 H=4511.50 C=4511.50 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:00:37+00:00 | gold-api.com | USD spot=4512.30/oz | O=4512.30 H=4512.30 C=4512.30 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:01:30+00:00 | gold-api.com | USD spot=4512.30/oz | O=4512.30 H=4512.30 C=4512.30 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:01:37+00:00 | gold-api.com | USD spot=4512.10/oz | O=4512.10 H=4512.10 C=4512.10 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:02:30+00:00 | gold-api.com | USD spot=4512.10/oz | O=4512.10 H=4512.10 C=4512.10 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:02:37+00:00 | gold-api.com | USD spot=4513.00/oz | O=4513.00 H=4513.00 C=4513.00 | 145.10/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:03:30+00:00 | gold-api.com | USD spot=4513.00/oz | O=4513.00 H=4513.00 C=4513.00 | 145.10/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:03:37+00:00 | gold-api.com | USD spot=4513.90/oz | O=4513.90 H=4513.90 C=4513.90 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:04:31+00:00 | gold-api.com | USD spot=4513.90/oz | O=4513.90 H=4513.90 C=4513.90 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:04:37+00:00 | gold-api.com | USD spot=4513.90/oz | O=4513.90 H=4513.90 C=4513.90 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:05:31+00:00 | gold-api.com | USD spot=4513.90/oz | O=4513.90 H=4513.90 C=4513.90 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:05:37+00:00 | gold-api.com | USD spot=4514.40/oz | O=4514.40 H=4514.40 C=4514.40 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:06:31+00:00 | gold-api.com | USD spot=4514.40/oz | O=4514.40 H=4514.40 C=4514.40 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:06:38+00:00 | gold-api.com | USD spot=4514.20/oz | O=4514.20 H=4514.20 C=4514.20 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:07:31+00:00 | gold-api.com | USD spot=4514.20/oz | O=4514.20 H=4514.20 C=4514.20 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:07:38+00:00 | gold-api.com | USD spot=4513.30/oz | O=4513.30 H=4513.30 C=4513.30 | 145.11/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:08:31+00:00 | gold-api.com | USD spot=4513.30/oz | O=4513.30 H=4513.30 C=4513.30 | 145.11/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:08:38+00:00 | gold-api.com | USD spot=4513.20/oz | O=4513.20 H=4513.20 C=4513.20 | 145.10/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:09:31+00:00 | gold-api.com | USD spot=4513.20/oz | O=4513.20 H=4513.20 C=4513.20 | 145.10/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:09:38+00:00 | gold-api.com | USD spot=4514.50/oz | O=4514.50 H=4514.50 C=4514.50 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:10:31+00:00 | gold-api.com | USD spot=4514.50/oz | O=4514.50 H=4514.50 C=4514.50 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:10:38+00:00 | gold-api.com | USD spot=4514.30/oz | O=4514.30 H=4514.30 C=4514.30 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:11:31+00:00 | gold-api.com | USD spot=4514.30/oz | O=4514.30 H=4514.30 C=4514.30 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:11:38+00:00 | gold-api.com | USD spot=4512.60/oz | O=4512.60 H=4512.60 C=4512.60 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:12:31+00:00 | gold-api.com | USD spot=4512.60/oz | O=4512.60 H=4512.60 C=4512.60 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:12:38+00:00 | gold-api.com | USD spot=4512.40/oz | O=4512.40 H=4512.40 C=4512.40 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:13:31+00:00 | gold-api.com | USD spot=4512.40/oz | O=4512.40 H=4512.40 C=4512.40 | 145.08/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:13:38+00:00 | gold-api.com | USD spot=4514.20/oz | O=4514.20 H=4514.20 C=4514.20 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:14:32+00:00 | gold-api.com | USD spot=4514.20/oz | O=4514.20 H=4514.20 C=4514.20 | 145.13/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:14:38+00:00 | gold-api.com | USD spot=4515.30/oz | O=4515.30 H=4515.30 C=4515.30 | 145.17/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:15:32+00:00 | gold-api.com | USD spot=4515.30/oz | O=4515.30 H=4515.30 C=4515.30 | 145.17/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:15:38+00:00 | gold-api.com | USD spot=4515.30/oz | O=4515.30 H=4515.30 C=4515.30 | 145.17/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:16:32+00:00 | gold-api.com | USD spot=4515.30/oz | O=4515.30 H=4515.30 C=4515.30 | 145.17/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:16:38+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:17:32+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:17:39+00:00 | gold-api.com | USD spot=4516.70/oz | O=4516.70 H=4516.70 C=4516.70 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:18:32+00:00 | gold-api.com | USD spot=4516.70/oz | O=4516.70 H=4516.70 C=4516.70 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:18:39+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:19:32+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:19:39+00:00 | gold-api.com | USD spot=4516.60/oz | O=4516.60 H=4516.60 C=4516.60 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:20:32+00:00 | gold-api.com | USD spot=4516.60/oz | O=4516.60 H=4516.60 C=4516.60 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:20:39+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:21:32+00:00 | gold-api.com | USD spot=4516.90/oz | O=4516.90 H=4516.90 C=4516.90 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:21:39+00:00 | gold-api.com | USD spot=4517.60/oz | O=4517.60 H=4517.60 C=4517.60 | 145.24/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:22:32+00:00 | gold-api.com | USD spot=4517.60/oz | O=4517.60 H=4517.60 C=4517.60 | 145.24/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:22:39+00:00 | gold-api.com | USD spot=4517.80/oz | O=4517.80 H=4517.80 C=4517.80 | 145.25/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:23:32+00:00 | gold-api.com | USD spot=4517.80/oz | O=4517.80 H=4517.80 C=4517.80 | 145.25/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:23:39+00:00 | gold-api.com | USD spot=4516.50/oz | O=4516.50 H=4516.50 C=4516.50 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:24:32+00:00 | gold-api.com | USD spot=4516.50/oz | O=4516.50 H=4516.50 C=4516.50 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:24:39+00:00 | gold-api.com | USD spot=4516.60/oz | O=4516.60 H=4516.60 C=4516.60 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:25:33+00:00 | gold-api.com | USD spot=4516.60/oz | O=4516.60 H=4516.60 C=4516.60 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:25:39+00:00 | gold-api.com | USD spot=4516.80/oz | O=4516.80 H=4516.80 C=4516.80 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:26:33+00:00 | gold-api.com | USD spot=4516.80/oz | O=4516.80 H=4516.80 C=4516.80 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:26:39+00:00 | gold-api.com | USD spot=4517.00/oz | O=4517.00 H=4517.00 C=4517.00 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:27:33+00:00 | gold-api.com | USD spot=4517.00/oz | O=4517.00 H=4517.00 C=4517.00 | 145.22/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:27:39+00:00 | gold-api.com | USD spot=4517.30/oz | O=4517.30 H=4517.30 C=4517.30 | 145.23/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:28:33+00:00 | gold-api.com | USD spot=4517.30/oz | O=4517.30 H=4517.30 C=4517.30 | 145.23/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:28:40+00:00 | gold-api.com | USD spot=4516.30/oz | O=4516.30 H=4516.30 C=4516.30 | 145.20/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:29:33+00:00 | gold-api.com | USD spot=4516.30/oz | O=4516.30 H=4516.30 C=4516.30 | 145.20/g | DB=gold_prices.sqlite
# OK 2025-12-26T08:29:40+00:00 | gold-api.com | USD spot=4516.50/oz | O=4516.50 H=4516.50 C=4516.50 | 145.21/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:30:28+00:00 | gold-api.com | USD spot=4522.30/oz | O=4522.30 H=4522.30 C=4522.30 | 145.40/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:30:34+00:00 | gold-api.com | USD spot=4522.20/oz | O=4522.20 H=4522.20 C=4522.20 | 145.39/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:47:45+00:00 | gold-api.com | USD spot=4515.20/oz | O=4515.20 H=4515.20 C=4515.20 | 145.17/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:49:43+00:00 | gold-api.com | USD spot=4514.80/oz | O=4514.80 H=4514.80 C=4514.80 | 145.15/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:50:36+00:00 | gold-api.com | USD spot=4514.60/oz | O=4514.60 H=4514.60 C=4514.60 | 145.15/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:50:43+00:00 | gold-api.com | USD spot=4514.60/oz | O=4514.60 H=4514.60 C=4514.60 | 145.15/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:51:36+00:00 | gold-api.com | USD spot=4514.40/oz | O=4514.40 H=4514.40 C=4514.40 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T10:51:43+00:00 | gold-api.com | USD spot=4514.40/oz | O=4514.40 H=4514.40 C=4514.40 | 145.14/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:18:50+00:00 | gold-api.com | USD spot=4512.20/oz | O=4512.20 H=4512.20 C=4512.20 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:18:56+00:00 | gold-api.com | USD spot=4512.20/oz | O=4512.20 H=4512.20 C=4512.20 | 145.07/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:22:41+00:00 | gold-api.com | USD spot=4511.60/oz | O=4511.60 H=4511.60 C=4511.60 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:22:48+00:00 | gold-api.com | USD spot=4511.60/oz | O=4511.60 H=4511.60 C=4511.60 | 145.05/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:26:24+00:00 | gold-api.com | USD spot=4511.40/oz | O=4511.40 H=4511.40 C=4511.40 | 145.04/g | DB=gold_prices.sqlite
# OK 2025-12-26T11:26:31+00:00 | gold-api.com | USD spot=4511.40/oz | O=4511.40 H=4511.40 C=4511.40 | 145.04/g | DB=gold_prices.sqlite

# %%
start_collector()  # pakt GOLD_INTERVAL_SEC

# %%
stop_collector()

# %%
stop_collector() 
start_collector()
