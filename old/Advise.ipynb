# %%
import os, threading

os.environ["GOLD_DB_PATH"] = "gold_prices.sqlite"
os.environ["GOLD_CURRENCY"] = "USD"
os.environ["GOLD_DB_POLL_SEC"] = "15"
os.environ["GOLD_WINDOW_N"] = "288"          # 24 uur bij 5m
os.environ["GOLD_BREAK_BUFFER_PCT"] = "0.01" # 1% buffer
os.environ["GOLD_PUSH_MODE"] = "signal"      # alleen ENTER meldingen

t = threading.Thread(target=run_forever, daemon=True)
t.start()
# Out:
# [watch] DB=gold_prices.sqlite table=gold_spot_prices currency=USD poll=10s state=gold_watch_state.json

# %%
import os
import time
import json
import sqlite3
import xml.etree.ElementTree as ET
from typing import Any, Dict, List, Optional, Tuple

import requests

# =========================
# Config (5m-friendly defaults)
# =========================
DB_PATH = os.getenv("GOLD_DB_PATH", "gold_prices.sqlite")
TABLE = os.getenv("GOLD_TABLE", "gold_spot_prices")
CURRENCY = os.getenv("GOLD_CURRENCY", "USD").upper()

# DB polling (hoe vaak kijken of er een nieuwe row is)
POLL_SEC = int(os.getenv("GOLD_DB_POLL_SEC", "15"))

# 5m sampling: 288 = 24 uur, 144 = 12 uur, 72 = 6 uur
WINDOW_N = int(os.getenv("GOLD_WINDOW_N", "288"))

# Break buffer (percentage van range) – 5m: 1% is vaak genoeg om ruis te filteren
BREAK_BUFFER_PCT = float(os.getenv("GOLD_BREAK_BUFFER_PCT", "0.01"))

# TP projecties (multiples van range)
TP1_MULT = float(os.getenv("GOLD_TP1_MULT", "0.6"))
TP2_MULT = float(os.getenv("GOLD_TP2_MULT", "1.2"))

# Afronding van levels (0 = hele dollars)
LEVEL_ROUND_DECIMALS = int(os.getenv("GOLD_LEVEL_ROUND_DECIMALS", "0"))

# Push gedrag:
# - "signal" = alleen push bij ENTER LONG/SHORT (aanrader)
# - "always" = bij elke nieuwe row push met levels
PUSH_MODE = os.getenv("GOLD_PUSH_MODE", "signal").lower()

# Prowl
PROWL_KEY_FILE = os.getenv("PROWL_KEY_FILE", "key.txt")
PROWL_APPLICATION = os.getenv("PROWL_APPLICATION", "Gold Setups (DB 5m)")
PROWL_PRIORITY = int(os.getenv("PROWL_PRIORITY", "0"))  # -2..2
PROWL_TIMEOUT = float(os.getenv("PROWL_TIMEOUT_SEC", "20"))
USER_AGENT = os.getenv("GOLD_USER_AGENT", "gold-db-setups/5m")

# State
STATE_FILE = os.getenv("GOLD_WATCH_STATE_FILE", "gold_setups_state.json")


# =========================
# Prowl
# =========================
def read_prowl_key(path: str) -> str:
    with open(path, "r", encoding="utf-8") as f:
        key = f.read().strip()
    if not key:
        raise RuntimeError(f"Prowl key file is empty: {path}")
    return key


def prowl_send(apikey: str, application: str, event: str, description: str, priority: int = 0) -> None:
    url = "https://api.prowlapp.com/publicapi/add"
    payload = {
        "apikey": apikey,
        "application": application,
        "event": event,
        "description": description,
        "priority": str(priority),
    }
    r = requests.post(url, data=payload, timeout=PROWL_TIMEOUT, headers={"User-Agent": USER_AGENT})

    if r.status_code == 406:
        raise RuntimeError("Prowl API limit exceeded (HTTP 406)")
    if r.status_code != 200:
        raise RuntimeError(f"Prowl HTTP {r.status_code}: {r.text[:200]}")

    try:
        root = ET.fromstring(r.text)
        err = root.find("error")
        if err is not None:
            code = err.attrib.get("code", "?")
            msg = (err.text or "").strip()
            raise RuntimeError(f"Prowl error {code}: {msg}")
    except ET.ParseError:
        pass


# =========================
# State
# =========================
def load_state() -> Dict[str, Any]:
    try:
        with open(STATE_FILE, "r", encoding="utf-8") as f:
            return json.load(f)
    except FileNotFoundError:
        return {}
    except Exception:
        return {}


def save_state(state: Dict[str, Any]) -> None:
    with open(STATE_FILE, "w", encoding="utf-8") as f:
        json.dump(state, f, ensure_ascii=False, indent=2)


# =========================
# DB (read-only)
# =========================
def fetch_latest_rows(db_path: str, table: str, currency: str, n: int) -> List[Dict[str, Any]]:
    q = f"""
    SELECT id, ts_utc, source, currency, price_per_troy_oz
    FROM {table}
    WHERE currency = ?
    ORDER BY id DESC
    LIMIT ?
    """
    with sqlite3.connect(db_path) as con:
        rows = con.execute(q, (currency, n)).fetchall()

    out: List[Dict[str, Any]] = []
    for r in rows:
        out.append({
            "id": int(r[0]),
            "ts_utc": str(r[1]),
            "source": str(r[2]),
            "currency": str(r[3]),
            "price": float(r[4]),
        })
    return out


# =========================
# Setup calculation
# =========================
def rr(x: float) -> float:
    return round(x, LEVEL_ROUND_DECIMALS)


def compute_setups(rows_newest_first: List[Dict[str, Any]]) -> Dict[str, Any]:
    if len(rows_newest_first) < 20:
        raise RuntimeError("Te weinig rows in DB om 5m setups stabiel te berekenen (minimaal 20).")

    latest = rows_newest_first[0]
    prices = [x["price"] for x in rows_newest_first]

    hi = max(prices)
    lo = min(prices)
    rng = max(hi - lo, 1e-9)
    mid = (hi + lo) / 2.0

    buf = rng * BREAK_BUFFER_PCT

    # Triggers: boven dag-high + buffer, onder dag-low - buffer
    long_trigger = hi + buf
    short_trigger = lo - buf

    # SL template: mid (range invalidation)
    sl = mid

    # TP templates: projecties vanaf range-extremes
    tp1_long = hi + rng * TP1_MULT
    tp2_long = hi + rng * TP2_MULT

    tp1_short = lo - rng * TP1_MULT
    tp2_short = lo - rng * TP2_MULT

    current = latest["price"]

    if current >= long_trigger:
        signal = "ENTER_LONG"
    elif current <= short_trigger:
        signal = "ENTER_SHORT"
    else:
        signal = "WAIT"

    return {
        "ts_utc": latest["ts_utc"],
        "source": latest["source"],
        "current": current,
        "hi": hi,
        "lo": lo,
        "range": rng,
        "mid": mid,
        "buf": buf,
        "long_trigger": long_trigger,
        "short_trigger": short_trigger,
        "sl": sl,
        "tp1_long": tp1_long,
        "tp2_long": tp2_long,
        "tp1_short": tp1_short,
        "tp2_short": tp2_short,
        "signal": signal,
    }


def format_signal_message(setup: Dict[str, Any]) -> Tuple[str, str, str]:
    cur = setup["current"]

    long_tr = setup["long_trigger"]
    short_tr = setup["short_trigger"]
    sl = setup["sl"]

    # Minimal output: alleen setup-waarden
    if setup["signal"] == "ENTER_LONG":
        event = f"ENTER LONG | Gold {CURRENCY} {rr(cur):.0f}"
        body = "\n".join([
            f"Prijs: {rr(cur):.0f}",
            "",
            f"LONG trigger:  >= {rr(long_tr):.0f}",
            f"SL: {rr(sl):.0f}",
            f"TP: {rr(setup['tp1_long']):.0f} → {rr(setup['tp2_long']):.0f}",
            "",
            f"Context (window {WINDOW_N}x5m): Hi={rr(setup['hi']):.0f} Lo={rr(setup['lo']):.0f} Range={rr(setup['range']):.0f}",
            f"Bron: {setup['source']} | Tijd (UTC): {setup['ts_utc']}",
        ])
        regime_key = f"ENTER_LONG|{rr(long_tr)}|{rr(short_tr)}"
        return event, body, regime_key

    if setup["signal"] == "ENTER_SHORT":
        event = f"ENTER SHORT | Gold {CURRENCY} {rr(cur):.0f}"
        body = "\n".join([
            f"Prijs: {rr(cur):.0f}",
            "",
            f"SHORT trigger: <= {rr(short_tr):.0f}",
            f"SL: {rr(sl):.0f}",
            f"TP: {rr(setup['tp1_short']):.0f} → {rr(setup['tp2_short']):.0f}",
            "",
            f"Context (window {WINDOW_N}x5m): Hi={rr(setup['hi']):.0f} Lo={rr(setup['lo']):.0f} Range={rr(setup['range']):.0f}",
            f"Bron: {setup['source']} | Tijd (UTC): {setup['ts_utc']}",
        ])
        regime_key = f"ENTER_SHORT|{rr(long_tr)}|{rr(short_tr)}"
        return event, body, regime_key

    # WAIT message (only if PUSH_MODE=always)
    event = f"Levels | Gold {CURRENCY} {rr(cur):.0f}"
    body = "\n".join([
        f"Prijs: {rr(cur):.0f}",
        "",
        "WAIT (geen entry)",
        f"LONG trigger:  >= {rr(long_tr):.0f}",
        f"SHORT trigger: <= {rr(short_tr):.0f}",
        f"SL (template): {rr(sl):.0f}",
        "",
        f"Context (window {WINDOW_N}x5m): Hi={rr(setup['hi']):.0f} Lo={rr(setup['lo']):.0f} Range={rr(setup['range']):.0f}",
        f"Bron: {setup['source']} | Tijd (UTC): {setup['ts_utc']}",
    ])
    regime_key = f"WAIT|{rr(long_tr)}|{rr(short_tr)}"
    return event, body, regime_key


# =========================
# Watch loop
# =========================
def run_forever() -> None:
    apikey = read_prowl_key(PROWL_KEY_FILE)
    state = load_state()

    last_seen_id = state.get("last_seen_id")
    last_regime_key = state.get("last_regime_key")

    print(f"[watch] 5m DB={DB_PATH} table={TABLE} currency={CURRENCY} poll={POLL_SEC}s window={WINDOW_N} push={PUSH_MODE}")

    while True:
        try:
            rows = fetch_latest_rows(DB_PATH, TABLE, CURRENCY, WINDOW_N)
            if not rows:
                time.sleep(POLL_SEC)
                continue

            latest_id = rows[0]["id"]

            # First run: set cursor, no push
            if last_seen_id is None:
                last_seen_id = latest_id
                state["last_seen_id"] = last_seen_id
                save_state(state)
                time.sleep(POLL_SEC)
                continue

            if latest_id > int(last_seen_id):
                setup = compute_setups(rows)
                event, body, regime_key = format_signal_message(setup)

                should_push = (PUSH_MODE == "always") or (setup["signal"] in ("ENTER_LONG", "ENTER_SHORT"))

                if should_push and regime_key != last_regime_key:
                    prowl_send(apikey, PROWL_APPLICATION, event, body, PROWL_PRIORITY)
                    last_regime_key = regime_key
                    state["last_regime_key"] = last_regime_key

                last_seen_id = latest_id
                state["last_seen_id"] = last_seen_id
                save_state(state)

        except Exception as e:
            print("[watch][ERROR]", str(e)[:400])

        time.sleep(POLL_SEC)


if __name__ == "__main__":
    run_forever()
# Out:
# [watch] 5m DB=gold_prices.sqlite table=gold_spot_prices currency=USD poll=5s window=120 push=signal
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4347.100098 4347.100098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4349.700195 4347.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4349.700195 4349.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4351.100098 4349.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4353.299805 4351.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4352.200195 4353.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4352.200195 4352.200195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4348.200195 4352.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4348.200195 4348.200195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4348.0 4348.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4348.0 4348.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4346.299805 4348.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4346.399902 4346.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.899902 4346.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.899902 4344.899902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.200195 4344.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4347.5 4344.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4347.0 4347.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4349.899902 4347.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4349.899902 4349.899902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4350.600098 4349.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4350.600098 4350.600098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.700195 4350.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4342.899902 4344.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4337.799805 4342.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4336.600098 4337.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4331.899902 4336.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4327.5 4331.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4321.100098 4327.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4318.600098 4321.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4317.799805 4318.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4317.799805 4317.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4310.299805 4317.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4310.299805 4310.299805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4310.299805 4310.299805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4311.0 4310.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4311.0 4311.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4301.899902 4311.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4305.200195 4301.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4307.200195 4305.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4311.5 4307.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4303.200195 4311.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4305.799805 4303.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4306.700195 4305.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4311.299805 4306.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4310.600098 4311.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4316.600098 4310.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4313.100098 4316.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4313.100098 4313.100098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4315.100098 4313.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4314.5 4315.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4314.5 4314.5
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4322.200195 4314.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4322.200195 4322.200195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4321.0 4322.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4319.799805 4321.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4318.5 4319.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4318.5 4318.5
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4313.600098 4318.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4313.600098 4313.600098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4304.100098 4313.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4301.299805 4304.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.399902 4301.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4295.299805 4296.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4293.200195 4295.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4293.200195 4293.200195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4289.799805 4293.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4289.799805 4289.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4285.200195 4289.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4285.200195 4285.200195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.399902 4285.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.600098 4283.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.399902 4278.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.399902 4281.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.700195 4281.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.100098 4279.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.100098 4278.100098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4277.799805 4278.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4277.799805 4277.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.200195 4277.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.899902 4281.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4287.299805 4284.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4288.700195 4287.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4288.700195 4288.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4286.600098 4288.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.0 4286.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.0 4283.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.799805 4283.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4276.600098 4283.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.0 4276.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4280.0 4278.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4280.0 4280.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.700195 4280.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.700195 4284.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4290.700195 4284.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4292.200195 4290.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4291.299805 4292.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4288.399902 4291.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4288.399902 4288.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4287.299805 4288.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4286.600098 4287.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.899902 4286.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.899902 4279.899902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.799805 4279.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.799805 4275.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4273.5 4275.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4269.200195 4273.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4263.600098 4269.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4266.899902 4263.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4266.899902 4266.899902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4262.100098 4266.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4265.799805 4262.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.799805 4265.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4272.899902 4278.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.399902 4272.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.5 4278.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.5 4279.5
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4279.5 4279.5
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4277.100098 4279.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.0 4277.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4274.399902 4275.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4274.200195 4274.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4273.700195 4274.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.799805 4273.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.799805 4275.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.100098 4275.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.0 4281.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4282.799805 4283.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.5 4282.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.200195 4284.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4283.299805 4281.200195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.0 4283.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4280.100098 4278.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4275.799805 4280.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.100098 4275.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4278.100098 4278.100098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4274.299805 4278.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4274.399902 4274.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4274.399902 4274.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4277.299805 4274.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4273.700195 4277.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4273.700195 4273.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4276.299805 4273.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4280.5 4276.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4282.0 4280.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4282.0 4282.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.299805 4282.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4285.0 4284.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4285.799805 4285.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4289.700195 4285.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4290.799805 4289.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4290.799805 4290.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4287.100098 4290.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4284.799805 4287.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4281.899902 4284.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.299805 4281.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.5 4296.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.600098 4297.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.700195 4296.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.700195 4297.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.799805 4297.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.799805 4297.799805
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.200195 4297.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4299.700195 4300.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4298.799805 4299.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4294.0 4298.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4293.0 4294.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4293.0 4293.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4291.799805 4293.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4294.600098 4291.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4295.399902 4294.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.200195 4295.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4295.399902 4296.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4295.899902 4295.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4295.899902 4295.899902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.5 4295.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.5 4296.5
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.299805 4296.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.899902 4297.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.5 4297.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.399902 4300.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4296.399902 4296.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4298.100098 4296.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4298.700195 4298.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4298.700195 4298.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4302.399902 4298.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4302.399902 4302.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4302.399902 4302.399902
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4303.799805 4302.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.899902 4303.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.100098 4300.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4301.700195 4300.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4298.5 4301.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4299.200195 4298.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4297.100098 4299.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.899902 4297.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.799805 4300.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.299805 4300.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4303.799805 4300.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4303.399902 4303.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4302.899902 4303.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4302.399902 4302.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4301.799805 4302.399902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4301.799805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4300.700195 4300.700195
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4339.899902 4300.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4340.600098 4339.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4341.0 4340.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4339.899902 4341.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4339.100098 4339.899902
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4339.600098 4339.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4340.399902 4339.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4341.600098 4340.399902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4343.299805 4341.600098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.5 4343.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4345.5 4344.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4345.0 4345.5
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4345.0 4345.0
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4341.299805 4345.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4342.100098 4341.299805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4342.100098 4342.100098
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4343.700195 4342.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4343.899902 4343.700195
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.200195 4343.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.0 4344.200195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4345.100098 4344.0
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4342.600098 4345.100098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4341.700195 4342.600098
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4336.799805 4341.700195
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4337.5 4336.799805
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4338.899902 4337.5
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4342.100098 4338.899902
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4344.0 4342.100098
# gestegen
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4343.299805 4344.0
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4338.100098 4343.299805
# gedaald
# # als we geen 'prev' hebben, geen vergelijking mogelijk
# 4339.200195 4338.100098
# gestegen
